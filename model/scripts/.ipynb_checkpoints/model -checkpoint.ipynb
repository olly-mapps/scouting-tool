# %%
import numpy as np
import pandas as pd
import torch as nn

# %%
df = pd.read_csv("../data/_data/possession_data.csv", index_col = 0)

# %%
df.head()
# Out:
#         Player_from     Squad_from       Comp_from  Mins_Per_90_from  \
# 1      Aaron Hickey        Bologna         Serie A              61.5
# 2      Aaron Lennon        Everton  Premier League              32.0
# 3  Aaron Leya Iseka       Toulouse         Ligue 1              43.0
# 4        Aaron Mooy   Huddersfield  Premier League              88.5
# 5    Aaron Ramsdale  Sheffield Utd  Premier League             100.0
#
#    Touches_Touches_from  Def.Pen_Touches_from  Def.3rd_Touches_from  \
# 1                  60.5                  66.5                  67.5
# 2                  25.0                  24.0                  30.0
# 3                  27.0                  33.5                  17.0
# 4                  92.5                  63.0                  68.5
# 5                  73.0                 100.0                  99.0
#
#    Mid.3rd_Touches_from  Att.3rd_Touches_from  Att.Pen_Touches_from  ...  \
# ...
